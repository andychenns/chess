# %%
import pandas as pd
import numpy as np
import re
import chess.pgn
import collections

# %%
#Load CSV file
df = pd.read_csv (r'/Users/longhaochen/chess/chess/data/lichess-04-2017.csv')

df.PGN = df.PGN.astype(str)

# %%
#Rename colume name for first column
df = df.rename(columns={"Unnamed: 0": "ID"})

# %%
#Filter data by PGN game that contains clk the clock time
df = df[df['PGN'].str.contains("clk")]

# %%
#Keep only ID and PGN
df = df[['ID','PGN']]

# %%
pd.options.display.max_colwidth = 10000

# %%
(df['PGN'][1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-607e9313d5d4> in <module>
# ----> 1 test_read = chess.pgn.read_game(df['PGN'][1])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/chess/pgn.py in read_game(handle, Visitor)
#    1473
#    1474     # Ignore leading empty lines and comments.
# -> 1475     line = handle.readline().lstrip("\ufeff")
#    1476     while line.isspace() or line.startswith("%") or line.startswith(";"):
#    1477         line = handle.readline()
#
# AttributeError: 'str' object has no attribute 'readline'

# %%
#First define a function that will decompoese a single PGN game then use list comprehension to loop through each PGN

PGN_output = pd.DataFrame(columns = ["ID", "Move", "Eval", "Clock"])
def PGN_Decompose(PGN, ID):
    #Load PGN data
    text_break = pd.Series(PGN.split(' '))
    #text_break = text_break.iloc[0].squeeze()
    #Search for data that we need
    eval_index = text_break[text_break.str.find("\[%eval")].index
    #move_number = text_break[eval_index-3]
    move = text_break[eval_index-2]
    evaluation = text_break[eval_index+1]
    clock_time = text_break[eval_index+3]
    #Reset index for all columns
    move.reset_index(drop=True, inplace=True)
    #move_number.reset_index(drop=True, inplace=True)
    evaluation.reset_index(drop=True, inplace=True)
    clock_time.reset_index(drop=True, inplace=True)
    #Generate series for ID for each move that we have
    match_id = pd.Series([ID] *len(move))
    #Concatenate columns
    temp = pd.concat([match_id,move,evaluation,clock_time],axis=1,ignore_index=True)
    temp.columns = ["ID", "Move", "Eval", "Clock"]
    #Concatenate temp to global dataframe
    #PGN_output = PGN_output.append(temp)
    return temp

# %%
import time

start = time.time()
print("hello")

PGN_output = pd.DataFrame(columns = ["ID", "Move", "Eval", "Clock"])

for index,row in df.head(10).iterrows():
    temp = pd.DataFrame()
    #Load PGN data
    text_break = pd.Series(row['PGN'].split(' '))
    #text_break = text_break.iloc[0].squeeze()
    #Search for data that we need
    eval_index = text_break[text_break.str.match("\[%eval")].index
    #move_number = text_break[eval_index-3]
    move = text_break[eval_index-2]
    evaluation = text_break[eval_index+1]
    clock_time = text_break[eval_index+3]
    #Reset index for all columns
    move.reset_index(drop=True, inplace=True)
    #move_number.reset_index(drop=True, inplace=True)
    evaluation.reset_index(drop=True, inplace=True)
    clock_time.reset_index(drop=True, inplace=True)
    #Generate series for ID for each move that we have
    match_id = pd.Series(row['ID']).repeat(len(move))
    #Concatenate columns
    temp = pd.concat([match_id,move,evaluation,clock_time],axis=1,ignore_index=True)
    temp.columns = ["ID", "Move", "Eval", "Clock"]
    #Concatenate temp to global dataframe
    PGN_output = PGN_output.append(temp)
    
    #temp = PGN_Decompose(row['PGN'], row['ID'])
    #PGN_output = PGN_output.append(temp)
    
end = time.time()
print(end - start)
# Out:
# hello
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-bfa60a07048b> in <module>
#      24     match_id = pd.Series(row['ID']).repeat(len(move))
#      25     #Concatenate columns
# ---> 26     temp = pd.concat([match_id,move,evaluation,clock_time],axis=1,ignore_index=True)
#      27     temp.columns = ["ID", "Move", "Eval", "Clock"]
#      28     #Concatenate temp to global dataframe
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     256     )
#     257
# --> 258     return op.get_result()
#     259
#     260
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     449
#     450                 index, columns = self.new_axes
# --> 451                 df = cons(data, index=index)
#     452                 df.columns = columns
#     453                 return df.__finalize__(self, method="concat")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     409             )
#     410         elif isinstance(data, dict):
# --> 411             mgr = init_dict(data, index, columns, dtype=dtype)
#     412         elif isinstance(data, ma.MaskedArray):
#     413             import numpy.ma.mrecords as mrecords
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     255             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     256         ]
# --> 257     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     258
#     259
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      80
#      81     # don't force copy because getting jammed in an ndarray anyway
# ---> 82     arrays = _homogenize(arrays, index, dtype)
#      83
#      84     # from BlockManager perspective
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in _homogenize(data, index, dtype)
#     309                 # Forces alignment. No need to copy data since we
#     310                 # are putting it into an ndarray later
# --> 311                 val = val.reindex(index, copy=False)
#     312         else:
#     313             if isinstance(val, dict):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in reindex(self, index, **kwargs)
#    4216     @Appender(generic.NDFrame.reindex.__doc__)
#    4217     def reindex(self, index=None, **kwargs):
# -> 4218         return super().reindex(index=index, **kwargs)
#    4219
#    4220     def drop(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4512         # perform the reindex on the axes
#    4513         return self._reindex_axes(
# -> 4514             axes, level, limit, tolerance, method, fill_value, copy
#    4515         ).__finalize__(self)
#    4516
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4533                 fill_value=fill_value,
#    4534                 copy=copy,
# -> 4535                 allow_dups=False,
#    4536             )
#    4537
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4575                 fill_value=fill_value,
#    4576                 allow_dups=allow_dups,
# -> 4577                 copy=copy,
#    4578             )
#    4579
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1249         # some axes don't allow reindexing with dups
#    1250         if not allow_dups:
# -> 1251             self.axes[axis]._can_reindex(indexer)
#    1252
#    1253         if axis >= self.ndim:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _can_reindex(self, indexer)
#    3360         # trying to reindex on an axis with duplicates
#    3361         if not self.is_unique and len(indexer):
# -> 3362             raise ValueError("cannot reindex from a duplicate axis")
#    3363
#    3364     def reindex(self, target, method=None, level=None, limit=None, tolerance=None):
#
# ValueError: cannot reindex from a duplicate axis

# %%
pd.Series(row['ID']).repeat(len(move))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7ab5b3f16643> in <module>
# ----> 1 pd.Series(row['ID']).repeat(len(move))
#
# NameError: name 'row' is not defined

# %%
import time
import collections
start = time.time()
print("hello")


def func2():
    store = collections.deque()
    for index,row in df.head(100).iterrows():
        text_break = pd.Series(row['PGN'].split(' '))
        eval_index = text_break[text_break.str.match("\[%eval")].index
        move = text_break[eval_index-2]
        store.append({'Move':text_break[eval_index-2],'Eval':text_break[eval_index+1],'Clock':text_break[eval_index+3],
                    'ID':pd.Series(row['ID']).repeat(len(move))})
    df_test = pd.DataFrame(store, columns=['Move','Eval','Clock','ID'])
    return df_test

end = time.time()
print(end - start)
# Out:
# hello
# 0.0002503395080566406

# %%
import timeit
print(timeit.timeit('func2()',number=10,globals={'func2':func2}))
# Out:
# 4.052840619000563

# %%
import time
import collections
from tqdm import tqdm


store = collections.deque()
for index,row in tqdm(df.head().iterrows()):
    text_break = pd.Series(row['PGN'].split(' '))
    eval_index = text_break[text_break.str.match("\[%eval")].index
    move = text_break[eval_index-2].reset_index(drop=True)
    evaluation = text_break[eval_index+1].reset_index(drop=True)
    clock_time = text_break[eval_index+3].reset_index(drop=True)
    store.append({'Move':move.values,'Eval':evaluation.values,'Clock':clock_time.values,
            'ID':int(pd.Series(row['ID']).values)})
df_test = pd.DataFrame(store, columns=['Move','Eval','Clock','ID'])

df_test.to_csv("~/chess/chess/data/lichess-04-2017_movebreakdown.csv",  header=True)
# Out:
# 10it [00:00, 235.92it/s]

# %%
df_test.set_index(['ID']).apply(pd.Series.explode).reset_index()
# Out:
#          ID  Move     Eval     Clock
# 0         0    d4    0.27]  0:05:00]
# 1         0   Nf6    0.29]  0:05:00]
# 2         0    c4    0.25]  0:04:59]
# 3         0    c5    0.36]  0:04:59]
# 4         0    d5    0.47]  0:04:58]
# ...     ...   ...      ...       ...
# 63393  1006   c3?   -9.17]  0:00:40]
# 63394  1006   e5?   -7.38]  0:00:06]
# 63395  1006  Bg3?   -8.54]  0:00:39]
# 63396  1006  Rc4?   -7.33]  0:00:01]
# 63397  1006   f4?  -12.02]  0:00:36]
#
# [63398 rows x 4 columns]

# %%
df_test2
# Out:
# <bound method DataFrame.explode of                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Move  \
# 0                                                                                                                                                                                                                                                            [d4, Nf6, c4, c5, d5, e6, Nc3, exd5, cxd5, d6, e4, g6, Nf3, Bg7, Be2, O-O, O-O, a6, a4, Re8, Nd2, Nbd7, f4, Rb8, a5, Qc7, Bf3, h6?, Nc4, b5, axb6, Nxb6, Nxb6?, Rxb6, g4, Nd7, e5?, dxe5, f5, g5?!, Ne4, f6?!, d6, Qb8, Qd5+, Kf8?!, Nxc5?, Rxd6, Qc4, Nxc5, Qxc5, Qb6??, Be3, Qd8??, Rfd1]
# 1                                                                                                                                                                                  [d4, d5, Bf4, Bf5, e3, e6, c3, Nf6, Bd3, Bxd3, Qxd3, Be7, Nd2, O-O, Ngf3, c5, c4, Nc6, b3?!, Qb6?!, dxc5, Bxc5, O-O, Nb4, Qc3, Rac8, a3, Nc6, b4, Be7, c5, Qa6, Rab1, b5, Rfe1, Rfd8, Nd4, Ne4, Nxe4, dxe4, Nxc6, Qxc6, Qe5?!, Rd5?!, Qc3, Bf6, Qc2, Rcd8, Bd6??, R5xd6, cxd6??, Qxc2, Rbc1, Qb2, d7, g6, Rc8, Qd2, Rec1, Kg7, h3, Rxd7, R8c5, Rd5, Rc7, Be5, R1c2?!]
# 0       0
# 1       1
# 2       2
# 3       3
# 4       4
# ..    ...
# 995  1002
# 996  1003
# 997  1004
# 998  1005
# 999  1006
#
# [1000 rows x 4 columns]>

# %%
# #Load PGN data
# text_break = df['PGN'].head(1).str.split(' ',expand=True)
# text_break = text_break.iloc[0].squeeze()
# #Search for data that we need
# move_number = text_break[text_break[text_break.str.match("\[%eval")].index-3]
# move = text_break[text_break[text_break.str.match("\[%eval")].index-2]
# evaluation = text_break[text_break[text_break.str.match("\[%eval")].index+1]
# clock_time = text_break[text_break[text_break.str.match("\[%clk")].index+1]
# #Reset index for all columns
# move.reset_index(drop=True, inplace=True)
# move_number.reset_index(drop=True, inplace=True)
# evaluation.reset_index(drop=True, inplace=True)
# clock_time.reset_index(drop=True, inplace=True)
# #Generate series for ID for each move that we have
# ID = pd.Series([1] *len(move))
# #Concatenate columns
# temp = pd.concat([ID,move_number,move,evaluation,clock_time],axis=1,ignore_index=True)
# temp.columns = ["ID", "Move Number", "Move", "Eval", "Clock"]
# #Concatenate temp to global dataframe
# PGN_output.append(temp)

# %%
# pd.set_option('display.max_rows', None)
# PGN_Decompose(df.iloc[3,1],df.iloc[3,0])
# Out:
#      ID Move Number    Move     Eval     Clock
# 0   1.0          1.      d4    0.12]  0:05:00]
# 1   1.0        1...      d5    0.15]  0:05:00]
# 2   1.0          2.     Bf4    0.07]  0:04:58]
# 3   1.0        2...     Bf5    0.06]  0:04:58]
# 4   1.0          3.      e3    0.06]  0:04:57]
# 5   1.0        3...      e6    0.08]  0:04:56]
# 6   1.0          4.      c3   -0.01]  0:04:53]
# 7   1.0        4...     Nf6    0.01]  0:04:54]
# 8   1.0          5.     Bd3     0.0]  0:04:51]
# 9   1.0        5...    Bxd3    0.02]  0:04:53]
# 10  1.0          6.    Qxd3   -0.01]  0:04:49]
# 11  1.0        6...     Be7     0.0]  0:04:41]
# 12  1.0          7.     Nd2     0.0]  0:04:42]
# 13  1.0        7...     O-O    0.05]  0:04:39]
# 14  1.0          8.    Ngf3    0.02]  0:04:40]
# 15  1.0        8...      c5    0.01]  0:04:34]
# 16  1.0          9.      c4    -0.3]  0:04:31]
# 17  1.0        9...     Nc6   -0.07]  0:04:04]
# 18  1.0         10.    b3?!   -0.96]  0:04:03]
# 19  1.0       10...   Qb6?!   -0.15]  0:03:26]
# 20  1.0         11.    dxc5   -0.61]  0:03:23]
# 21  1.0       11...    Bxc5   -0.27]  0:03:22]
# 22  1.0         12.     O-O   -0.28]  0:03:20]
# 23  1.0       12...     Nb4    0.04]  0:02:53]
# 24  1.0         13.     Qc3   -0.12]  0:02:53]
# 25  1.0       13...    Rac8    0.14]  0:02:43]
# 26  1.0         14.      a3     0.0]  0:02:44]
# 27  1.0       14...     Nc6   -0.02]  0:02:27]
# 28  1.0         15.      b4    0.06]  0:02:43]
# 29  1.0       15...     Be7    0.04]  0:02:20]
# 30  1.0         16.      c5    0.02]  0:02:39]
# 31  1.0       16...     Qa6    0.49]  0:01:58]
# 32  1.0         17.    Rab1    0.28]  0:02:31]
# 6   3.0          4.     Bg2    0.13]  0:07:56]
# 7   3.0        4...      e6    0.19]  0:07:53]
# 8   3.0          5.     O-O    0.14]  0:07:56]
# 9   3.0        5...      c5    0.27]  0:07:49]
# 10  3.0          6.    dxc5   -0.01]  0:07:52]
# 11  3.0        6...    Bxc5    0.14]  0:07:48]
# 12  3.0          7.      b3   -0.25]  0:07:37]
# 13  3.0        7...     O-O    -0.2]  0:07:45]
# 14  3.0          8.     Bb2    -0.2]  0:07:36]
# 15  3.0        8...      d6    0.15]  0:07:42]
# 16  3.0          9.    Nbd2    -0.3]  0:07:32]
# 17  3.0        9...    Nbd7   -0.23]  0:07:40]
# 18  3.0         10.      c4   -0.16]  0:07:30]
# 19  3.0       10...      a6   -0.23]  0:07:35]
# 20  3.0         11.     Qc2    -0.5]  0:07:25]
# 21  3.0       11...     Rc8   -0.49]  0:07:18]
# 22  3.0         12.    Rfd1    -0.6]  0:07:00]
# 23  3.0       12...     Qb6   -0.51]  0:07:14]
# 24  3.0         13.      e3    -0.7]  0:06:56]
# 25  3.0       13...  bxc4?!     0.0]  0:07:07]
# 26  3.0         14.    Nxc4     0.0]  0:06:54]
# 27  3.0       14...     Qa7     0.0]  0:07:06]
# 28  3.0         15.     Qe2     0.0]  0:06:33]
# 29  3.0       15...    Nb6?    1.41]  0:05:58]
# 30  3.0         16.    Nxd6    1.15]  0:06:19]
# 31  3.0       16...    Bxd6    1.31]  0:05:54]
# 32  3.0         17.    Rxd6    1.27]  0:06:18]
# 33  3.0       17...     Ne4    1.64]  0:05:53]
# 34  3.0         18.     Rd4    1.48]  0:06:06]
# 35  3.0       18...  Rfd8?!    2.28]  0:05:43]
# 36  3.0         19.     Ne5    1.93]  0:05:43]
# 37  3.0       19...    Rxd4     2.1]  0:05:38]
# 38  3.0         20.    Bxd4    1.94]  0:05:42]
# 39  3.0       20...    Nd6?    4.17]  0:05:31]
# 40  3.0         21.     Nd7    4.04]  0:05:23]
# 41  3.0       21...    Bxg2    3.81]  0:05:06]
# 42  3.0         22.    Nxb6    3.74]  0:05:21]
# 43  3.0       22...   Qb7?!    4.34]  0:05:02]
# 44  3.0         23.    Nxc8    4.35]  0:05:12]
# 45  3.0       23...    Nxc8    4.25]  0:04:49]
# 46  3.0         24.   Rc1?!    3.56]  0:05:05]
# 47  3.0       24...     Nd6    3.61]  0:04:39]
# 48  3.0         25.    Qg4?    2.59]  0:04:38]
# 49  3.0       25...   Bh1??      #1]  0:04:28]
# 50  NaN         NaN     NaN      NaN  0:04:34]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-110-75fff1bbf806> in <module>
# ----> 1 df.iloc([0,0])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __call__(self, axis)
#     110
#     111         if axis is not None:
# --> 112             axis = self.obj._get_axis_number(axis)
#     113         new_self.axis = axis
#     114         return new_self
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     400     @classmethod
#     401     def _get_axis_number(cls, axis):
# --> 402         axis = cls._AXIS_ALIASES.get(axis, axis)
#     403         if is_integer(axis):
#     404             if axis in cls._AXIS_NAMES:
#
# TypeError: unhashable type: 'list'

# %%
move.reset_index(drop=True, inplace=True)
move_number.reset_index(drop=True, inplace=True)

test_df = pd.concat([move,move_number],axis=1,ignore_index=True)
test_df
# Out:
#         0      1
# 0      d4     1.
# 1     Nf6   1...
# 2      c4     2.
# 3      c5   2...
# 4      d5     3.
# 5      e6   3...
# 6     Nc3     4.
# 7    exd5   4...
# 8    cxd5     5.
# 9      d6   5...
# 10     e4     6.
# 11     g6   6...
# 12    Nf3     7.
# 13    Bg7   7...
# 14    Be2     8.
# 15    O-O   8...
# 16    O-O     9.
# 17     a6   9...
# 18     a4    10.
# 19    Re8  10...
# 20    Nd2    11.
# 21   Nbd7  11...
# 22     f4    12.
# 23    Rb8  12...
# 24     a5    13.
# 25    Qc7  13...
# 26    Bf3    14.
# 27    h6?  14...
# 28    Nc4    15.
# 29     b5  15...
# 30   axb6    16.
# 31   Nxb6  16...
# 32  Nxb6?    17.
# 33   Rxb6  17...
# 34     g4    18.
# 35    Nd7  18...
# 36    e5?    19.
# 37   dxe5  19...
# 38     f5    20.
# 39   g5?!  20...
# 40    Ne4    21.
# 41   f6?!  21...
# 42     d6    22.
# 43    Qb8  22...
# 44   Qd5+    23.
# 45  Kf8?!  23...
# 46  Nxc5?    24.
# 47   Rxd6  24...
# 48    Qc4    25.
# 49   Nxc5  25...
# 50   Qxc5    26.
# 51  Qb6??  26...
# 52    Be3    27.
# 53  Qd8??  27...
# 54   Rfd1    28.

# %%
# Out:
# 1         d4
# 9        Nf6
# 17        c4
# 25        c5
# 33        d5
# 41        e6
# 49       Nc3
# 57      exd5
# 65      cxd5
# 73        d6
# 81        e4
# 89        g6
# 97       Nf3
# 105      Bg7
# 113      Be2
# 121      O-O
# 129      O-O
# 137       a6
# 145       a4
# 153      Re8
# 161      Nd2
# 169     Nbd7
# 177       f4
# 185      Rb8
# 193       a5
# 201      Qc7
# 209      Bf3
# 217      h6?
# 225      Nc4
# 233       b5
# 241     axb6
# 249     Nxb6
# 257    Nxb6?
# 265     Rxb6
# 273       g4
# 281      Nd7
# 289      e5?
# 297     dxe5
# 305       f5
# 313     g5?!
# 321      Ne4
# 329     f6?!
# 337       d6
# 345      Qb8
# 353     Qd5+
# 361    Kf8?!
# 369    Nxc5?
# 377     Rxd6
# 385      Qc4
# 393     Nxc5
# 401     Qxc5
# 409    Qb6??
# 417      Be3
# 425    Qd8??
# 433     Rfd1
# Name: 0, dtype: object

# %%
temp
# Out:
#      ID Move Number Move Eval Clock
# 0   NaN          1.  NaN  NaN   NaN
# 8   NaN        1...  NaN  NaN   NaN
# 16  NaN          2.  NaN  NaN   NaN
# 24  NaN        2...  NaN  NaN   NaN
# 32  NaN          3.  NaN  NaN   NaN
# 40  NaN        3...  NaN  NaN   NaN
# 48  NaN          4.  NaN  NaN   NaN
# 56  NaN        4...  NaN  NaN   NaN
# 64  NaN          5.  NaN  NaN   NaN
# 72  NaN        5...  NaN  NaN   NaN
# 80  NaN          6.  NaN  NaN   NaN
# 88  NaN        6...  NaN  NaN   NaN
# 96  NaN          7.  NaN  NaN   NaN
# 104 NaN        7...  NaN  NaN   NaN
# 112 NaN          8.  NaN  NaN   NaN
# 120 NaN        8...  NaN  NaN   NaN
# 128 NaN          9.  NaN  NaN   NaN
# 136 NaN        9...  NaN  NaN   NaN
# 144 NaN         10.  NaN  NaN   NaN
# 152 NaN       10...  NaN  NaN   NaN
# 160 NaN         11.  NaN  NaN   NaN
# 168 NaN       11...  NaN  NaN   NaN
# 176 NaN         12.  NaN  NaN   NaN
# 184 NaN       12...  NaN  NaN   NaN
# 192 NaN         13.  NaN  NaN   NaN
# 200 NaN       13...  NaN  NaN   NaN
# 208 NaN         14.  NaN  NaN   NaN
# 216 NaN       14...  NaN  NaN   NaN
# 224 NaN         15.  NaN  NaN   NaN
# 232 NaN       15...  NaN  NaN   NaN
# 240 NaN         16.  NaN  NaN   NaN
# 248 NaN       16...  NaN  NaN   NaN
# 256 NaN         17.  NaN  NaN   NaN
# 264 NaN       17...  NaN  NaN   NaN
# 272 NaN         18.  NaN  NaN   NaN
# 280 NaN       18...  NaN  NaN   NaN
# 288 NaN         19.  NaN  NaN   NaN
# 296 NaN       19...  NaN  NaN   NaN
# 304 NaN         20.  NaN  NaN   NaN
# 312 NaN       20...  NaN  NaN   NaN
# 320 NaN         21.  NaN  NaN   NaN
# 328 NaN       21...  NaN  NaN   NaN
# 336 NaN         22.  NaN  NaN   NaN
# 344 NaN       22...  NaN  NaN   NaN
# 352 NaN         23.  NaN  NaN   NaN
# 360 NaN       23...  NaN  NaN   NaN
# 368 NaN         24.  NaN  NaN   NaN
# 376 NaN       24...  NaN  NaN   NaN
# 384 NaN         25.  NaN  NaN   NaN
# 392 NaN       25...  NaN  NaN   NaN
# 400 NaN         26.  NaN  NaN   NaN
# 408 NaN       26...  NaN  NaN   NaN
# 416 NaN         27.  NaN  NaN   NaN
# 424 NaN       27...  NaN  NaN   NaN
# 432 NaN         28.  NaN  NaN   NaN

# %%
PGN_string = df['PGN'].head(1)
text_break = PGN_string.str.split(' ',expand=True)
text_break = text_break.iloc[0].squeeze()
text_break[text_break.str.match("\[%eval")].index+1
# Out:
# Int64Index([  4,  12,  20,  28,  36,  44,  52,  60,  68,  76,  84,  92, 100,
#             108, 116, 124, 132, 140, 148, 156, 164, 172, 180, 188, 196, 204,
#             212, 220, 228, 236, 244, 252, 260, 268, 276, 284, 292, 300, 308,
#             316, 324, 332, 340, 348, 356, 364, 372, 380, 388, 396, 404, 412,
#             420, 428, 436],
#            dtype='int64')

# %%
#Eval for white and black
text_break[text_break[text_break.str.match("\[%eval")].index+1]
text_break[text_break[text_break.str.match("\[%clk")].index+1]
# Out:
# 6      0:05:00]
# 14     0:05:00]
# 22     0:04:59]
# 30     0:04:59]
# 38     0:04:58]
# 46     0:04:59]
# 54     0:04:56]
# 62     0:04:59]
# 70     0:04:55]
# 78     0:04:58]
# 86     0:04:53]
# 94     0:04:58]
# 102    0:04:39]
# 110    0:04:57]
# 118    0:04:35]
# 126    0:04:56]
# 134    0:04:33]
# 142    0:04:55]
# 150    0:04:32]
# 158    0:04:55]
# 166    0:04:29]
# 174    0:04:54]
# 182    0:04:27]
# 190    0:04:39]
# 198    0:04:23]
# 206    0:04:38]
# 214    0:04:22]
# 222    0:04:35]
# 230    0:04:20]
# 238    0:04:27]
# 246    0:04:18]
# 254    0:04:26]
# 262    0:04:10]
# 270    0:04:17]
# 278    0:04:06]
# 286    0:04:01]
# 294    0:03:47]
# 302    0:03:59]
# 310    0:03:45]
# 318    0:03:56]
# 326    0:03:18]
# 334    0:03:49]
# 342    0:03:12]
# 350    0:03:49]
# 358    0:03:09]
# 366    0:03:37]
# 374    0:02:36]
# 382    0:03:29]
# 390    0:02:22]
# 398    0:03:26]
# 406    0:02:21]
# 414    0:03:24]
# 422    0:02:19]
# 430    0:03:14]
# 438    0:02:14]
# Name: 0, dtype: object

# %%
text_break[text_break[text_break.str.match("\[%eval")].index-3]
# Out:
# 0         1.
# 8       1...
# 16        2.
# 24      2...
# 32        3.
# 40      3...
# 48        4.
# 56      4...
# 64        5.
# 72      5...
# 80        6.
# 88      6...
# 96        7.
# 104     7...
# 112       8.
# 120     8...
# 128       9.
# 136     9...
# 144      10.
# 152    10...
# 160      11.
# 168    11...
# 176      12.
# 184    12...
# 192      13.
# 200    13...
# 208      14.
# 216    14...
# 224      15.
# 232    15...
# 240      16.
# 248    16...
# 256      17.
# 264    17...
# 272      18.
# 280    18...
# 288      19.
# 296    19...
# 304      20.
# 312    20...
# 320      21.
# 328    21...
# 336      22.
# 344    22...
# 352      23.
# 360    23...
# 368      24.
# 376    24...
# 384      25.
# 392    25...
# 400      26.
# 408    26...
# 416      27.
# 424    27...
# 432      28.
# Name: 0, dtype: object

# %%
s = pd.Series(["a1a2", "b1", "c1"], index=["A", "B", "C"])
s.str.extractall(r"[ab](\d)")
# Out:
#          0
#   match
# A 0      1
#   1      2
# B 0      1

# %%
text_break
# Out:
# 0    [1., d4, {, [%eval, 0.27], [%clk, 0:05:00], }, 1..., Nf6, {, [%eval, 0.29], [%clk, 0:05:00], }, 2., c4, {, [%eval, 0.25], [%clk, 0:04:59], }, 2..., c5, {, [%eval, 0.36], [%clk, 0:04:59], }, 3., d5, {, [%eval, 0.47], [%clk, 0:04:58], }, 3..., e6, {, [%eval, 0.64], [%clk, 0:04:59], }, 4., Nc3, {, [%eval, 0.47], [%clk, 0:04:56], }, 4..., exd5, {, [%eval, 0.49], [%clk, 0:04:59], }, 5., cxd5, {, [%eval, 0.49], [%clk, 0:04:55], }, 5..., d6, {, [%eval, 0.48], [%clk, 0:04:58], }, 6., e4, {, [%eval, 0.48], [%clk, 0:04:53], }, 6..., g6, {, [%eval, 0.64], [%clk, 0:04:58], }, 7., Nf3, {, [%eval, ...]
# Name: PGN, dtype: object

# %%
type(first)
# Out:
# pandas.core.series.Series

# %%
test = re.search("1. ", str(df['PGN'].head(1)))

# %%
test.span()
# Out:
# (5, 8)

# %%
test1 = re.search("1... ", str(df['PGN'].head(1)))

# %%
test1.span()
# Out:
# (43, 48)
